# %%
# 드라이브 연동
from google.colab import drive
drive.mount('/content/drive')

#이 부분은 처음 한번만 실행하면 됌.
# !pip install selenium
# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# !pip install fake_useragent
# !apt-get install g++ openjdk-8-jdk python-dev python3-dev
# !pip3 install JPype1-py3
# !pip3 install konlpy
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# !pip install pytube 3
# !pip install youtube_transcript_api


# -*- coding: UTF-8 -*-
import requests
from urllib.request import urlopen
from bs4 import BeautifulSoup
from urllib.parse import quote_plus
from datetime import datetime
from selenium.webdriver.common.keys import Keys
import csv
import time
import re
from tqdm import tqdm
from selenium import webdriver
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from konlpy.tag import Twitter
from collections import Counter
from wordcloud import WordCloud
from nltk.tokenize import RegexpTokenizer
import json
import urllib.request as req
from fake_useragent import UserAgent
from nltk.corpus import wordnet as wn
from nltk import pos_tag
import nltk
from pytube import YouTube
import sys
from time import sleep
from youtube_transcript_api import YouTubeTranscriptApi
# Out:
# Mounted at /content/drive
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 39.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.9/384.9 KB 27.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 KB 5.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...
# Hit:1 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:2 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# Get:4 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease [18.1 kB]
# ...

# %%
# !pip uninstall pytube
# !pip install git+https://github.com/nficano/pytube


# -*- coding: UTF-8 -*-
import requests
from urllib.request import urlopen
from bs4 import BeautifulSoup
from urllib.parse import quote_plus
from datetime import datetime
from selenium.webdriver.common.keys import Keys
import csv
import time
import re
from tqdm import tqdm
from selenium import webdriver
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from konlpy.tag import Twitter
from collections import Counter
from wordcloud import WordCloud
from nltk.tokenize import RegexpTokenizer
import json
import urllib.request as req
from fake_useragent import UserAgent
from nltk.corpus import wordnet as wn
from nltk import pos_tag
import nltk
from pytube import YouTube
import sys
from time import sleep
from youtube_transcript_api import YouTubeTranscriptApi
# Out:
# Found existing installation: pytube 12.1.2
# Uninstalling pytube-12.1.2:
#   Would remove:
#     /usr/local/bin/pytube
#     /usr/local/lib/python3.8/dist-packages/pytube-12.1.2.dist-info/*
#     /usr/local/lib/python3.8/dist-packages/pytube/*
# Proceed (Y/n)? Y
#   Successfully uninstalled pytube-12.1.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/nficano/pytube to /tmp/pip-req-build-5iydplw0
#   Running command git clone --filter=blob:none --quiet https://github.com/nficano/pytube /tmp/pip-req-build-5iydplw0
#   Resolved https://github.com/nficano/pytube to commit d3d18691b3e99b2d3b4d620446b088a1c32896c6
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pytube: filename=pytube-12.1.2-py3-none-any.whl size=57060 sha256=58d8ef4c3453602acbc2e5dafb9e4fc6de506eafc875c177f3ec5957f1616e21
# ...

# %%
# 유튜브 링크 가져오기
f = open("체크용.txt", "r",encoding='utf-8')

lst = []
while True:
    line = f.readline().strip()
    if not line: break
    lst.append(line)

print(lst)

# 빈 DF 생성
df = pd.DataFrame()
#df
# Out:
# ['https://youtube.com/watch?v=g5ymJNLURRI', 'https://youtube.com/watch?v=e-kSGNzu0hM', 'https://youtube.com/watch?v=rz_rus8Vg6Q', 'https://youtube.com/watch?v=Lsla5yJpDi8', 'https://youtube.com/watch?v=eSHIh6jjUt0', 'https://youtube.com/watch?v=sSYHRqQaNx8', 'https://youtube.com/watch?v=84FatKnHhJI', 'https://youtube.com/watch?v=kQppigzTxyk', 'https://youtube.com/watch?v=Fop2oskTug8', 'https://youtube.com/watch?v=Hq-24K59Yuo', 'https://youtube.com/watch?v=MaB9ADTiv9s', 'https://youtube.com/watch?v=0UkQM18PLYI', 'https://youtube.com/watch?v=8Jb1ES7lvFw', 'https://youtube.com/watch?v=xxBe8oV58cc', 'https://youtube.com/watch?v=spRNoC7cxgs', 'https://youtube.com/watch?v=HvHLKlOTwdE', 'https://youtube.com/watch?v=2YGGXrFv4GI', 'https://youtube.com/watch?v=Zak0XAGVm4c', 'https://youtube.com/watch?v=dX609qIJ7dI', 'https://youtube.com/watch?v=mQvt5XJaALo', 'https://youtube.com/watch?v=9wdF-s--Kwo', 'https://youtube.com/watch?v=TnkdoEZhTbc', 'https://youtube.com/watch?v=_K8JMJ-SrVc', 'https:/
# ...

# %%
for i in lst:
  yt= YouTube(i)
  youtubeDic={'영상 길이': [yt.length]}
  df= df.append(pd.Series(youtubeDic), ignore_index=True)
#df.to_csv('/content/drive/MyDrive/Youtube_Crawling/유튜브 크롤링1.csv', index=True)
df.to_csv('아이폰리뷰_업로더정보.csv', encoding = 'utf8', index=True)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-31ae85e33592> in <module>
#       1 for i in lst:
#       2   yt= YouTube(i)
# ----> 3   youtubeDic={'영상 길이': [yt.length]}
#       4   df= df.append(pd.Series(youtubeDic), ignore_index=True)
#       5 #df.to_csv('/content/drive/MyDrive/Youtube_Crawling/유튜브 크롤링1.csv', index=True)
#
# /usr/local/lib/python3.8/dist-packages/pytube/__main__.py in length(self)
#     381         :rtype: int
#     382         """
# --> 383         return int(self.vid_info.get('videoDetails', {}).get('lengthSeconds'))
#     384
#     385     @property
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'NoneType'

# %%
# 빈 리스트 생성
title_list= [] # 제목
a= []


for i in lst:
  yt= YouTube(i)
  a.append(yt.length)

print(a)

with open('like, comment.csv','w',encoding='UTF-8') as f:
  writer= csv.writer(f)
  writer.writerow(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-cca7ef89133a> in <module>
#       6 for i in lst:
#       7   yt= YouTube(i)
# ----> 8   a.append(yt.length)
#       9
#      10 print(a)
#
# /usr/local/lib/python3.8/dist-packages/pytube/__main__.py in length(self)
#     381         :rtype: int
#     382         """
# --> 383         return int(self.vid_info.get('videoDetails', {}).get('lengthSeconds'))
#     384
#     385     @property
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'NoneType'

# %%
###
from pytube import YouTube 
yt = YouTube("https://youtube.com/watch?v=TVgQ_tgWMyU")
print(f"title={yt.title}")

# %%
###
from pytube import YouTube 
for i in lst:
  yt = YouTube(i)
  try:
    print(f"views={yt.views}")
  except TypeError:
    print('error')

# %%
for i in lst:
  yt= YouTube(i)
  youtubeDic={
      '제목': [yt.title],
      '영상 길이': [yt.length]}
  df= df.append(pd.Series(youtubeDic), ignore_index=True)
#df.to_csv('/content/drive/MyDrive/Youtube_Crawling/유튜브 크롤링1.csv', index=True)
df.to_csv('아이폰리뷰_업로더정보.csv', encoding = 'utf8', index=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pytube/__main__.py in title(self)
#     340         try:
# --> 341             self._title = self.vid_info['videoDetails']['title']
#     342         except KeyError:
#
# KeyError: 'videoDetails'
#
# During handling of the above exception, another exception occurred:
#
# PytubeError                               Traceback (most recent call last)
# <ipython-input-17-6e1d3f84597f> in <module>
#       2   yt= YouTube(i)
#       3   youtubeDic={
# ----> 4       '제목': [yt.title],
#       5       '영상 길이': [yt.length]}
#       6   df= df.append(pd.Series(youtubeDic), ignore_index=True)
#
# /usr/local/lib/python3.8/dist-packages/pytube/__main__.py in title(self)
#     344             #  if it doesn't, ask for a report.
#     345             self.check_availability()
# ...

# %%
# 유튜브 링크 가져오기
f = open("체크용.txt", "r",encoding='utf-8')

lst = []
while True:
    line = f.readline().strip()
    if not line: break
    lst.append(line)

print(lst)

# 빈 DF 생성
df = pd.DataFrame()
#df
# Out:
# ['https://youtube.com/watch?v=g5ymJNLURRI', 'https://youtube.com/watch?v=e-kSGNzu0hM', 'https://youtube.com/watch?v=rz_rus8Vg6Q', 'https://youtube.com/watch?v=Lsla5yJpDi8', 'https://youtube.com/watch?v=eSHIh6jjUt0', 'https://youtube.com/watch?v=sSYHRqQaNx8', 'https://youtube.com/watch?v=84FatKnHhJI', 'https://youtube.com/watch?v=kQppigzTxyk', 'https://youtube.com/watch?v=Fop2oskTug8', 'https://youtube.com/watch?v=Hq-24K59Yuo', 'https://youtube.com/watch?v=MaB9ADTiv9s', 'https://youtube.com/watch?v=0UkQM18PLYI', 'https://youtube.com/watch?v=8Jb1ES7lvFw', 'https://youtube.com/watch?v=xxBe8oV58cc', 'https://youtube.com/watch?v=spRNoC7cxgs', 'https://youtube.com/watch?v=HvHLKlOTwdE', 'https://youtube.com/watch?v=2YGGXrFv4GI', 'https://youtube.com/watch?v=Zak0XAGVm4c', 'https://youtube.com/watch?v=dX609qIJ7dI', 'https://youtube.com/watch?v=mQvt5XJaALo', 'https://youtube.com/watch?v=9wdF-s--Kwo', 'https://youtube.com/watch?v=TnkdoEZhTbc', 'https://youtube.com/watch?v=_K8JMJ-SrVc', 'https:/
# ...

# %%
###
from pytube import YouTube 
for i in lst:
  yt = YouTube(i)
  try:
    print(i, {yt.title}, {yt.length})
  except KeyError:
    print('error')
    
#with open('like, comment.csv','w',encoding='UTF-8') as f:
#  writer= csv.writer(f)
#  writer.writerow(a)
# Out:
# https://youtube.com/watch?v=g5ymJNLURRI {'iPhone 13 Review: Lowkey Great!'} {1082}
# https://youtube.com/watch?v=e-kSGNzu0hM {'iPhone 13 Review: Pros and Cons'} {397}
# https://youtube.com/watch?v=rz_rus8Vg6Q {'Apple iPhone 13 review'} {588}
# https://youtube.com/watch?v=Lsla5yJpDi8 {'iPhone 13 review: worth the upgrade?'} {753}
# https://youtube.com/watch?v=eSHIh6jjUt0 {'Should You Buy iPhone 13 in 2023?'} {759}
# https://youtube.com/watch?v=sSYHRqQaNx8 {'iPhone 13 in 2023 - worth it? (Review)'} {661}
# https://youtube.com/watch?v=84FatKnHhJI {'iPhone 13 Unboxing - Are they ACTUALLY Good!?'} {1012}
# https://youtube.com/watch?v=kQppigzTxyk {'iPhone 13 Review - Pretty much Pro'} {932}
# https://youtube.com/watch?v=Fop2oskTug8 {'iPhone 13 Unboxing & Impressions!'} {662}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ...

# %%
###
from pytube import YouTube 
for i in lst:
  yt = YouTube(i)
  try:
    print(f"title={yt.title}")
  except:
    print('error')
    
#with open('like, comment.csv','w',encoding='UTF-8') as f:
#  writer= csv.writer(f)
#  writer.writerow(a)
# Out:
# title=iPhone 13 Review: Lowkey Great!
# title=iPhone 13 Review: Pros and Cons
# title=Apple iPhone 13 review
# title=iPhone 13 review: worth the upgrade?
# title=Should You Buy iPhone 13 in 2023?
# title=iPhone 13 in 2023 - worth it? (Review)
# title=iPhone 13 Unboxing - Are they ACTUALLY Good!?
# title=iPhone 13 Review - Pretty much Pro
# title=iPhone 13 Unboxing & Impressions!
# title=iPhone 13 Review: Should You Buy In 2023?
# title=iPhone 14 vs iPhone 13 Review - The Easy Choice!
# title=iPhone 13 1 Year Later: the good and the bad…
# title=iPhone 13 In 2023! (Still Worth Buying?) (Review)
# title=iPhone 13 In 2022! (Review)
# title=iPhone 13 One Year Later - Better than the iPhone 14??
# title=The funny thing about the iPhone 13 in 2023!
# title=iPhone 13 | Unboxing all new models!
# title=Apple iPhone 13 Review - What Apple Didn't tell you !
# title=IPHONE 13 UNBOXING + SET UP 2022 *white new iphone*
# title=iPhone 13 Review: 1 Year Later! (Still Worth It?)
# ...

# %%
###
from pytube import YouTube 
for i in lst:
  yt = YouTube(i)
  try:
    print(f"length={yt.length}")
  except TypeError:
    print('error')

#with open('like, comment.csv','w',encoding='UTF-8') as f:
#  writer= csv.writer(f)
#  writer.writerow(a)

# %%
for i in lst:
  yt= YouTube(i)
  youtubeDic={
      '제목': [yt.title],
      '영상 길이': [yt.length],
      '업로더': [yt.author],
      '게시날짜': [yt.publish_date],
      '조회수': [yt.views],
      '키워드': [yt.keywords],
      '영상설명': [yt.description]}
  df= df.append(pd.Series(youtubeDic), ignore_index=True)
#df.to_csv('/content/drive/MyDrive/Youtube_Crawling/유튜브 크롤링1.csv', index=True)
df.to_csv('아이폰리뷰_업로더정보.csv', encoding = 'utf8', index=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pytube/__main__.py in title(self)
#     340         try:
# --> 341             self._title = self.vid_info['videoDetails']['title']
#     342         except KeyError:
#
# KeyError: 'videoDetails'
#
# During handling of the above exception, another exception occurred:
#
# PytubeError                               Traceback (most recent call last)
# <ipython-input-6-14839a720b1e> in <module>
#       2   yt= YouTube(i)
#       3   youtubeDic={
# ----> 4       '제목': [yt.title],
#       5       '영상 길이': [yt.length],
#       6       '업로더': [yt.author],
#
# /usr/local/lib/python3.8/dist-packages/pytube/__main__.py in title(self)
#     344             #  if it doesn't, ask for a report.
#     345             self.check_availability()
# --> 346             raise exceptions.PytubeError(
# ...

# %% [markdown]
# **유튜브 영상 자막 다운로드**

# %%
# 유튜브 링크 가져오기
f = open("Iphone_14_English_link1.txt", "r",encoding='utf-16')

lst1 = []
while True:
    line = f.readline().strip()
    if not line: break
    lst1.append(line)

print(lst1)

# %%
# 빈 리스트 생성
a=[]

# 유튜브 링크 가져오기
f = open("Iphone_14_English_link1.txt", "r",encoding='utf-16')

lst1 = []
while True:
    line = f.readline().strip()
    if not line: break
    lst1.append(line)

print(lst1)

# %%
for i in lst1:
  YTP= YouTubeTranscriptApi.get_transcript(i)
  a.append(YTP)
print(a)

# %%
with open('유튜브 자막 크롤링.csv','w',encoding='UTF-8') as f:
  writer= csv.writer(f)
  writer.writerow(a)

# %%
with open('유튜브 자막 크롤링.txt','w',encoding='UTF-8') as f:
    for name in a:
        f.write('\n')

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# 빈 리스트 생성
b=[]


for i in lst1:
  transcript_list = YouTubeTranscriptApi.list_transcripts(i)
  for transcript in transcript_list:
    TCT= transcript.translate('en').fetch()
  b.append(TCT)
print(b)

# %%
with open("자막.csv", 'w') as file:
  writer = csv.writer(file)
  writer.writerow(b)

# %% [markdown]
# 파라미터 정리

# %%
#@title
# import ssl
# ssl._create_default_https_context = ssl._create_stdlib_context

DOWNLOAD_FOLDER = "/content/drive/MyDrive/Youtube_Crawling"
#가져올 링크 넣기
url = "https://www.youtube.com/watch?v=WzyScfSdsWs"
yt = YouTube(url)

print("title : ", yt.title) # 영상제목
print("length : ", yt.length) # 영상 길이
print("author : ", yt.author) # 영상 게시자
print("publish_date : ", yt.publish_date) # 업로드 날짜
print("views : ", yt.views) # 조회수 
print("keywords : ", yt.keywords) # 키워드
print("description : ", yt.description) # 영상 설명
print("thumbnail_url : ", yt.thumbnail_url) # 썸네일 url

# from pytube import Playlist
# p = Playlist('https://www.youtube.com/watch?v=cJZCQdAYRFM&list=PLKRZTF1Q1uwaeTOXQ3BwQLQJJ32c3wlUW')
# for video in p.videos:
#     video.streams.first().download(DOWNLOAD_FOLDER)
#     print("다운로드 완료")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-77f1861b5ece> in <module>
#       6 #가져올 링크 넣기
#       7 url = "https://www.youtube.com/watch?v=WzyScfSdsWs"
# ----> 8 yt = YouTube(url)
#       9
#      10 print("title : ", yt.title) # 영상제목
#
# NameError: name 'YouTube' is not defined

# %%
#@title
# import ssl
# ssl._create_default_https_context = ssl._create_stdlib_context

DOWNLOAD_FOLDER = "/content/drive/MyDrive/Youtube_Crawling"
#가져올 링크 넣기
url = "https://www.youtube.com/watch?v=WzyScfSdsWs"
yt = YouTube(url)

print("title : ", yt.title) # 영상제목
print("length : ", yt.length) # 영상 길이
print("author : ", yt.author) # 영상 게시자
print("publish_date : ", yt.publish_date) # 업로드 날짜
print("views : ", yt.views)
print("keywords : ", yt.keywords)
print("description : ", yt.description)
print("thumbnail_url : ", yt.thumbnail_url)

# from pytube import Playlist
# p = Playlist('https://www.youtube.com/watch?v=cJZCQdAYRFM&list=PLKRZTF1Q1uwaeTOXQ3BwQLQJJ32c3wlUW')
# for video in p.videos:
#     video.streams.first().download(DOWNLOAD_FOLDER)
#     print("다운로드 완료")

# %%
#@title
f = open("Iphone_14_English_link.txt", "r",encoding='utf-16')

lst = []
while True:
    line = f.readline().strip()
    if not line: break
    lst.append(line)

print(lst)

# %%
#@title
#파일 불러오기
f = open("/content/drive/MyDrive/유튜브 링크/Iphone_14_English_link.txt", 'r',encoding='utf-16')
cnt = 0
while True:
    line = f.readline()
    if not line: break
    print(line)
f.close()

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# retrieve the available transcripts
transcript_list = YouTubeTranscriptApi.list_transcripts('XYn6w_zNqeE')

# iterate over all available transcripts
for transcript in transcript_list:

    # the Transcript object provides metadata properties
    print(
        transcript.video_id,
        transcript.language,
        transcript.language_code,
        # whether it has been manually created or generated by YouTube
        transcript.is_generated,
        # whether this transcript can be translated or not
        transcript.is_translatable,
        # a list of languages the transcript can be translated to
        transcript.translation_languages,
    )

    # fetch the actual transcript data
    #print(transcript.fetch())

    # translating the transcript will return another transcript object
    print(transcript.translate('en').fetch())

# you can also directly filter for the language you are looking for, using the transcript list
transcript = transcript_list.find_transcript(['en'])  


# or automatically generated ones  
transcript = transcript_list.find_generated_transcript(['en'])
