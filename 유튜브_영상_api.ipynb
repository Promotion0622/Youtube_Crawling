# %%
# Install
# !pip install pytube3
# !pip install -U pytube
# !pip uninstall pytub  e pytube3 pytubexpython -m pip install git+https://github.com/nficano/pytube

from pytube import YouTube
import pandas as pd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 56 kB 4.0 MB/s
# ...
#
# Usage:
#   pip3 uninstall [options] <package> ...
#   pip3 uninstall [options] -r <requirements file> ...
#
# no such option: -m

# %%
video_url = 'https://www.youtube.com/watch?v=oTtbIf1TfL8&list=PLo4NVFqamDK8dZrnL_PCvhxSFvf7CZpiK&index=54&ab_channel=iJustine'#@param {type:"string"}
yt = YouTube(video_url)

# %%
yt.captions.all()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated function all (This object can be treated as a dictionary).
#   """Entry point for launching an IPython kernel.
# [<Caption lang="English (auto-generated)" code="a.en">,
#  <Caption lang="English - Default" code="en.ehkg1hFWq8A">]

# %%
caption = yt.captions.get_by_language_code('a.en')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   """Entry point for launching an IPython kernel.

# %%
video_url = 'https://www.youtube.com/watch?v=oTtbIf1TfL8&list=PLo4NVFqamDK8dZrnL_PCvhxSFvf7CZpiK&index=54&ab_channel=iJustine'#@param {type:"string"}
yt = YouTube(video_url)

# %%
print("vid_info :", yt.vid_info) #
# Out:
# vid_info : {'responseContext': {'visitorData': 'CgtkOXBCSkxmWkt6RSjmoNybBg%3D%3D', 'serviceTrackingParams': [{'service': 'GFEEDBACK', 'params': [{'key': 'ipcc', 'value': '0'}, {'key': 'is_viewed_live', 'value': 'False'}, {'key': 'is_alc_surface', 'value': 'false'}, {'key': 'logged_in', 'value': '0'}, {'key': 'e', 'value': '1714243,23882685,23888716,23918597,23934970,23946420,23966208,23983296,23998056,24001373,24004644,24007246,24034168,24036948,24063124,24065483,24074379,24077241,24080738,24117491,24120819,24123943,24135310,24135692,24140247,24161116,24162919,24164186,24169501,24181174,24187043,24187377,24191629,24197450,24199724,24211178,24217535,24219713,24230619,24234977,24241378,24248091,24248956,24255165,24255543,24255545,24260783,24262346,24263796,24265964,24267564,24267919,24268142,24278596,24279196,24282970,24283093,24283556,24285788,24287327,24290971,24292955,24293803,24299747,24390675,24392058,24396137,24400749,24401544,24401557,24402891,24405623,24406318,24407199,24407665
# ...

# %%
#리뷰어 정보
print("author : ", yt.author) # 영상 게시자
print("channel_url :", yt.channel_url) # 채널 주소

#동영상 정보
print("title : ", yt.title) # 영상제목
print("length : ", yt.length) # 영상 길이
print("publish_date : ", yt.publish_date) # 업로드 날짜
print("views : ", yt.views) # 조회수
print("keywords : ", yt.keywords) #키워드
print("평균평점 :", yt.rating) # 평균 평점
print("description : ", yt.description) # 영상 설명
print("captions :", yt.captions) # 자막 형식
# Out:
# author :  iJustine
# channel_url : https://www.youtube.com/channel/UCey_c7U86mJGz1VJWH5CYPA
# title :  Full iPhone 14 Lineup unboxing and review!
# length :  1322
# publish_date :  2022-09-14 00:00:00
# views :  1707190
# keywords :  ['ijustine']
# 평균평점 : None
# description :  The new iPhone 14, iPhone 14 Pro, and iPhone 14 Pro Max!
# ❤️➡️ PLEASE SUBSCRIBE FOR MORE VIDEOS! http://www.youtube.com/subscription_center?add_user=ijustine
# 🎶 MUSIC I USE - http://share.epidemicsound.com/NNNGs
#
# ➡️Purchase mKeynote here! https://mvfx.co/mKeynote-with-iJustine
# ✅FRIEND ME HERE:
# http://twitter.com/ijustine
# http://instagram.com/ijustine
# http://facebook.com/ijustine
#
# 🐷 MY NEW PROJECT: http://twitter.com/jpig
#
#
# ———
#
#
# 🎥 WHAT I USE TO MAKE VIDEOS 📷
#
# CAMERAS:
# Sony a7s III - https://geni.us/qNnJ
# Sony a1 - https://geni.us/z21JP
# Sony a7 IV - https://geni.us/BBL26o
# Insta 360 ONE X2 - https://geni.us/UEXR
# Insta 360 ONE RS - https://geni.us/FXer
# ...

# %%
yt.captions.all()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated function all (This object can be treated as a dictionary).
#   """Entry point for launching an IPython kernel.
# [<Caption lang="English (auto-generated)" code="a.en">,
#  <Caption lang="English - Default" code="en.ehkg1hFWq8A">]

# %%
caption = yt.captions.get_by_language_code('a.en')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   """Entry point for launching an IPython kernel.

# %%
# 언어로 자막 선택하기
## 영어 자막 1순위로 선택하기. 만약 영어 자막이 없다면 자막 리스트 중 첫 번째 자막 선택하기-아마 자동번역
caption = yt.captions.get_by_language_code('a.en')
if caption == None:
    caption = yt.captions.all()[0]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# 자막 살펴보기(xml 포맷)
caption.xml_captions
# Out:
# '<?xml version="1.0" encoding="utf-8" ?><timedtext format="3">\n<head>\n<ws id="0"/>\n<ws id="1" mh="2" ju="0" sd="3"/>\n<wp id="0"/>\n<wp id="1" ap="6" ah="20" av="100" rc="2" cc="40"/>\n</head>\n<body>\n<w t="0" id="1" wp="1" ws="1"/>\n<p t="0" d="4620" w="1"><s ac="248">hey</s><s t="420" ac="248"> guys</s><s t="539" ac="248"> it&#39;s</s><s t="780" ac="248"> Justine</s><s t="1199" ac="248"> and</s><s t="1439" ac="248"> today</s><s t="1680" ac="248"> we</s><s t="1979" ac="248"> are</s></p>\n<p t="2090" d="2530" w="1" a="1">\n</p>\n<p t="2100" d="5100" w="1"><s ac="248">unboxing</s><s t="480" ac="248"> all</s><s t="779" ac="248"> of</s><s t="900" ac="248"> the</s><s t="1020" ac="248"> iPhone</s><s t="1200" ac="247"> 14s</s><s t="2040" ac="248"> we</s><s t="2400" ac="248"> have</s></p>\n<p t="4610" d="2590" w="1" a="1">\n</p>\n<p t="4620" d="6780" w="1"><s ac="248">the</s><s t="300" ac="248"> new</s><s t="420" ac="248"> iPhone</s><s t="659" ac="248"> 14</s><s t="1139" ac="248"> pro</
# ...

# %%
from pytube import YouTube
 
link = 'https://www.youtube.com/watch?v=oTtbIf1TfL8&list=PLo4NVFqamDK8dZrnL_PCvhxSFvf7CZpiK&index=54&ab_channel=iJustine'
src = YouTube(link)
 
# prints all available captions in various languages.
print('Captions Available: ', src.captions)
print()
 
# Getting only English captions by specifying 'en' as parameter
en_caption = src.captions.get_by_language_code('en')
print(en_caption.xml_captions)
 
# Instead of Captions in XML format we are converting it to string format.
en_caption_convert_to_srt = (en_caption.generate_srt_captions())
print(en_caption_convert_to_srt)
# Out:
# Captions Available:  {'a.en': <Caption lang="English (auto-generated)" code="a.en">, 'en.ehkg1hFWq8A': <Caption lang="English - Default" code="en.ehkg1hFWq8A">}
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   # This is added back by InteractiveShellApp.init_path()
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-cb5ebb13c701> in <module>
#      10 # Getting only English captions by specifying 'en' as parameter
#      11 en_caption = src.captions.get_by_language_code('en')
# ---> 12 print(en_caption.xml_captions)
#      13
#      14 # Instead of Captions in XML format we are converting it to string format.
#
# AttributeError: 'NoneType' object has no attribute 'xml_captions'

# %%
import pytube
from pytube import Playlist, YouTube

url = "https://www.youtube.com/watch?v=oTtbIf1TfL8&list=PLo4NVFqamDK8dZrnL_PCvhxSFvf7CZpiK&index=54&ab_channel=iJustine"
p = Playlist(url)

for v in p.videos[:3]:
    print("trying to get captions for:", v.title)
    print(v.captions["a.en"].generate_srt_captions())

# %%
    def xml_caption_to_srt(self, xml_captions: str) -> str:
        segments = []
        root = ElementTree.fromstring(xml_captions)
        i=0
        for child in list(root.iter("body"))[0]:
            if child.tag == 'p':
                caption = ''
                if len(list(child))==0:
                    # instead of 'continue'
                    caption = child.text
                for s in list(child):
                    if s.tag == 's':
                        caption += ' ' + s.text
                caption = unescape(caption.replace("\n", " ").replace("  ", " "),)
                try:
                    duration = float(child.attrib["d"])/1000.0
                except KeyError:
                    duration = 0.0
                start = float(child.attrib["t"])/1000.0
                end = start + duration
                sequence_number = i + 1  # convert from 0-indexed to 1.
                line = "{seq}\n{start} --> {end}\n{text}\n".format(
                    seq=sequence_number,
                    start=self.float_to_srt_time_format(start),
                    end=self.float_to_srt_time_format(end),
                    text=caption,
                )
                segments.append(line)
                i += 1
        return "\n".join(segments).strip()

# %%
# 자막 살펴보기(srt 포맷)
print(yt.captions['a.en'].generate_srt_captions())

# %%
# 자막 다운받기: download("파일명")
caption.download( yt.title )
